# %% [markdown]
# testing reaction evaluator

# %%
from lipidmaps import process_csv
dataset = process_csv("../tests/data/inputs/input_selected.csv", validate_data=True, use_refmet=True, use_headgroups=True, taxonomy_group="mammalia")
# Out:
# Evaluating pair: reactant headgroup=1 product headgroup=LMGP10010000
# Evaluating pair: reactant headgroup=LMGP0105AA00 product headgroup=LMGP01010000
# Evaluating pair: reactant headgroup=LMGP01010000 product headgroup=1
# Evaluating pair: reactant headgroup=1 product headgroup=LMGL03010000
# Evaluating pair: reactant headgroup=CDP product headgroup=LMGP06010000
# Evaluating pair: reactant headgroup=LMGP01050000 product headgroup=LMGP01010000
# Evaluating pair: reactant headgroup=LMGP01010000 product headgroup=LMGP10010000
# Evaluating pair: reactant headgroup=LMGP01010000 product headgroup=LMGP01050000
# Evaluating pair: reactant headgroup=LMGP10010000 product headgroup=CDP
# Evaluating pair: reactant headgroup=Ceramide product headgroup=N
# Evaluating pair: reactant headgroup=LMGP01010000 product headgroup=LMGP0105AA00
# Evaluating pair: reactant headgroup=LMGP01010000 product headgroup=1
# Evaluating pair: reactant headgroup=Sphingomyelin product headgroup=Ceramide
# Evaluating pair: reactant headgroup=Sphingomyelin product headgroup=Ceramide
# Evaluating pair: reactant headgroup=LMGP10050000 product headgroup=LMGP10010000
# Evaluating pair: reactant headgroup=Ceramide product headgroup=fatty
# Evaluating pair: reactant headgroup=LMFA07050000 product headgroup=Ceramide
# Evaluating pair: reactant headgroup=LMGP10010000 product headgroup=1
# Evaluating pair: reactant headgroup=LMGP04010000 product headgroup=Cardiolipin
# Evaluating pair: reactant headgroup=1 product headgroup=LMGP02010000
# Evaluating pair: reactant headgroup=LMGP10050000 product headgroup=LMGL01010000
# Evaluating pair: reactant headgroup=LMGP03050000 product headgroup=LMGP03010000
# Evaluating pair: reactant headgroup=LMGL03010000 product headgroup=1
# Evaluating pair: reactant headgroup=N product headgroup=Ceramide
# Evaluating pair: reactant headgroup=LMGP05010000 product headgroup=LMGP04010000
# Evaluating pair: reactant headgroup=LMGP01020000 product headgroup=LMGP01060000
# Evaluating pair: reactant headgroup=LMGP01050000 product headgroup=LMGP10050000
# Evaluating pair: reactant headgroup=LMGP01050000 product headgroup=LMGL01010000
# Evaluating pair: reactant headgroup=LMGP01010000 product headgroup=LMGP03010000
# Evaluating pair: reactant headgroup=18 product headgroup=Ceramide
# Evaluating pair: reactant headgroup=LMGP03010000 product headgroup=LMGP02010000
# Evaluating pair: reactant headgroup=LMGP02010000 product headgroup=LMGP01010000
# Evaluating pair: reactant headgroup=1 product headgroup=LMGP01010000
# Evaluating pair: reactant headgroup=LMGP02050000 product headgroup=LMGP02010000
# Evaluating pair: reactant headgroup=LMGP02010000 product headgroup=LMGP03010000
# Evaluating pair: reactant headgroup=LMGP02020000 product headgroup=LMGP02030000
# Evaluating pair: reactant headgroup=DG product headgroup=LMGP02020000
# Evaluating pair: reactant headgroup=DG product headgroup=LMGP01020000
# Evaluating pair: reactant headgroup=LMGP10020000 product headgroup=DG
# Evaluating pair: reactant headgroup=LMGP01010000 product headgroup=Sphingomyelin
# Evaluating pair: reactant headgroup=PIP product headgroup=LMGP06010000
# Evaluating pair: reactant headgroup=LMGP06010000 product headgroup=PIP
# Evaluating pair: reactant headgroup=LMGP06010000 product headgroup=PIP
# Evaluating pair: reactant headgroup=PIP product headgroup=LMGP06010000
# Evaluating pair: reactant headgroup=LMGP06010000 product headgroup=PIP
# Evaluating pair: reactant headgroup=DG product headgroup=Galactosylalkylacylglycerol
# Evaluating pair: reactant headgroup=Ceramide product headgroup=GlcCer
# Evaluating pair: reactant headgroup=GlcCer product headgroup=Ceramide
# Evaluating pair: reactant headgroup=Ceramide product headgroup=GalCer
# Evaluating pair: reactant headgroup=GalCer product headgroup=Ceramide
# Evaluating pair: reactant headgroup=LMGP01010000 product headgroup=Phosphatidylethanol
# Evaluating pair: reactant headgroup=LMGP01010000 product headgroup=1
# Evaluating pair: reactant headgroup=PIP2 product headgroup=1
# /lipidmaps/lipidmaps_py/venv/lib64/python3.9/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'dev.lipidmaps.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
