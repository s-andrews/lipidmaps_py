# %% [markdown]
# testing reaction evaluator

# %%
from lipidmaps import process_csv
dataset = process_csv("../tests/data/inputs/demo/BioPan_large_demo.csv", validate_data=True, use_refmet=True, use_headgroups=True, taxonomy_group="mammalia")
# Out:
# /lipidmaps/lipidmaps_py/venv/lib64/python3.9/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'dev.lipidmaps.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
from lipidmaps.data.utils.reaction_evaluator import ReactionEvaluator
from lipidmaps.data.utils.lipid_reaction_rules import lipid_reaction_rules
evaluator = ReactionEvaluator(lipid_reaction_rules)
ev = evaluator.annotate_reactions(dataset.reactions, dataset=dataset)
# Out:
#  Reactanttt lipids: DG 30:0, DG 30:1, DG 32:0, DG 32:1, DG 32:2
#  Product lipids: PA 30:0, PA 32:0, PA 32:1, PA 32:2, PA 34:1
# Dataset contains 559 lipids, with 25 unique generic_lm_ids.
# Evaluated reaction 1: possible=False, explanation=No matching species in dataset for this reaction.
# Evaluated reaction 3: possible=False, explanation=Missing generic_lm_id for reactants/products in dataset.
#  Reactanttt lipids: PC 28:0, PC 30:0, PC 30:1, PC 32:0, PC 32:1
#  Product lipids: DG 30:0, DG 30:1, DG 32:0, DG 32:1, DG 32:2
# Dataset contains 559 lipids, with 25 unique generic_lm_ids.
# Evaluated reaction 7: possible=False, explanation=No matching species in dataset for this reaction.
# Evaluated reaction 11: possible=False, explanation=Missing generic_lm_id for reactants/products in dataset.
# Evaluated reaction 13: possible=False, explanation=Missing generic_lm_id for reactants/products in dataset.
# ...

# %%
ev = None
ev = evaluator.evaluate_reaction(dataset.reactions[0], dataset=dataset)
# Out:
#  Reactanttt lipids: DG 30:0, DG 30:1, DG 32:0, DG 32:1, DG 32:2
#  Product lipids: PA 30:0, PA 32:0, PA 32:1, PA 32:2, PA 34:1
# Dataset contains 559 lipids, with 25 unique generic_lm_ids.
